# %% [markdown]
# # Authors: Juan Andrés Méndez Galvis

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import sklearn as sk
# Import linear regression from scikit-learn
from sklearn.linear_model import LinearRegression
# Import train_test_split function
from sklearn.model_selection import train_test_split
# Import metrics from scikit-learn
from sklearn import metrics
from sklearn.model_selection import cross_val_score
# Import standard scaler
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# # 3. Desarrollo de modelos analiticos

# %% [markdown]
# ## Entendimiento de los datos

# %%
df_airbnb_listings = pd.read_csv('listings.csv')
df_airbnb_listings.head()
# Out:
#        id                          listing_url       scrape_id last_scraped  \
# 0  528022  https://www.airbnb.com/rooms/528022  20221205143541   2022-12-05
# 1    2818    https://www.airbnb.com/rooms/2818  20221205143541   2022-12-05
# 2   20168   https://www.airbnb.com/rooms/20168  20221205143541   2022-12-05
# 3   27886   https://www.airbnb.com/rooms/27886  20221205143541   2022-12-05
# 4   28871   https://www.airbnb.com/rooms/28871  20221205143541   2022-12-05
#
#             source                                               name  \
# 0      city scrape                                     Somewhere Else
# 1      city scrape          Quiet Garden View Room & Super Fast Wi-Fi
# 2  previous scrape       Studio with private bathroom in the centre 1
# 3      city scrape  Romantic, stylish B&B houseboat in canal district
# 4      city scrape                            Comfortable double room
#
#                                          description  \
# 0  Highlights<br />*Located only 5 minutes from C...
# 1  Quiet Garden View Room & Super Fast Wi-Fi<br /...
# 2  17th century Dutch townhouse in the heart of t...
# 3  Stylish and romantic houseboat on fantastic hi...
# 4  <b>The space</b><br />In a monumental house ri...
#
#                                neighborhood_overview  \
# 0                                                NaN
# 1  Indische Buurt ("Indies Neighborhood") is a ne...
# 2  Located just in between famous central canals....
# 3         Central, quiet, safe, clean and beautiful.
# 4       Flower market , Leidseplein , Rembrantsplein
#
#                                          picture_url  host_id  ...  \
# 0  https://a0.muscache.com/pictures/bf6fa79c-5863...  2594559  ...
# 1  https://a0.muscache.com/pictures/10272854/8dcc...     3159  ...
# 2  https://a0.muscache.com/pictures/69979628/fd6a...    59484  ...
# 3  https://a0.muscache.com/pictures/02c2da9d-660e...    97647  ...
# 4  https://a0.muscache.com/pictures/160889/362340...   124245  ...
#
#   review_scores_communication review_scores_location review_scores_value  \
# 0                        4.90                   4.78                4.72
# 1                        4.98                   4.69                4.81
# 2                        4.62                   4.87                4.49
# 3                        4.92                   4.89                4.79
# 4                        4.94                   4.97                4.83
#
#                     license instant_bookable calculated_host_listings_count  \
# 0  0363 9289 A94D 5C21 A579                f                              1
# 1  0363 5F3A 5684 6750 D14D                f                              1
# 2  0363 CBB3 2C10 0C2A 1E29                t                              2
# 3  0363 974D 4986 7411 88D8                t                              1
# 4  0363 607B EA74 0BD8 2F6F                f                              2
#
#   calculated_host_listings_count_entire_homes  \
# 0                                           0
# 1                                           0
# 2                                           0
# 3                                           0
# 4                                           0
#
#   calculated_host_listings_count_private_rooms  \
# 0                                            1
# 1                                            1
# 2                                            2
# 3                                            1
# 4                                            2
#
#   calculated_host_listings_count_shared_rooms reviews_per_month
# 0                                           0              3.30
# 1                                           0              1.88
# 2                                           0              2.18
# 3                                           0              1.83
# 4                                           0              3.03
#
# [5 rows x 75 columns]

# %%
# Print the name of the columns
print(df_airbnb_listings.columns)
# Out:
# Index(['id', 'listing_url', 'scrape_id', 'last_scraped', 'source', 'name',
#        'description', 'neighborhood_overview', 'picture_url', 'host_id',
#        'host_url', 'host_name', 'host_since', 'host_location', 'host_about',
#        'host_response_time', 'host_response_rate', 'host_acceptance_rate',
#        'host_is_superhost', 'host_thumbnail_url', 'host_picture_url',
#        'host_neighbourhood', 'host_listings_count',
#        'host_total_listings_count', 'host_verifications',
#        'host_has_profile_pic', 'host_identity_verified', 'neighbourhood',
#        'neighbourhood_cleansed', 'neighbourhood_group_cleansed', 'latitude',
#        'longitude', 'property_type', 'room_type', 'accommodates', 'bathrooms',
#        'bathrooms_text', 'bedrooms', 'beds', 'amenities', 'price',
#        'minimum_nights', 'maximum_nights', 'minimum_minimum_nights',
#        'maximum_minimum_nights', 'minimum_maximum_nights',
#        'maximum_maximum_nights', 'minimum_nights_avg_ntm',
#        'maximum_nights_avg_ntm', 'calendar_updated', 'has_availability',
#        'availability_30', 'availability_60', 'availability_90',
#        'availability_365', 'calendar_last_scraped', 'number_of_reviews',
#        'number_of_reviews_ltm', 'number_of_reviews_l30d', 'first_review',
#        'last_review', 'review_scores_rating', 'review_scores_accuracy',
#        'review_scores_cleanliness', 'review_scores_checkin',
#        'review_scores_communication', 'review_scores_location',
#        'review_scores_value', 'license', 'instant_bookable',
#        'calculated_host_listings_count',
#        'calculated_host_listings_count_entire_homes',
#        'calculated_host_listings_count_private_rooms',
#        'calculated_host_listings_count_shared_rooms', 'reviews_per_month'],
#       dtype='object')

# %% [markdown]
# # Tipos de columnas y categorias

# %% [markdown]
# - Numeric:
#
#         - id, scrape_id, host_id, accommodates, bathrooms, bedrooms, beds, price, minimum_nights, maximum_nights, minimum_minimum_nights, maximum_minimum_nights, minimum_maximum_nights, maximum_maximum_nights, minimum_nights_avg_ntm, maximum_nights_avg_ntm, availability_30, availability_60, availability_90, availability_365, number_of_reviews, number_of_reviews_ltm, number_of_reviews_l30d, review_scores_rating, review_scores_accuracy, review_scores_cleanliness, review_scores_checkin, review_scores_communication, review_scores_location, review_scores_value, calculated_host_listings_count, calculated_host_listings_count_entire_homes, calculated_host_listings_count_private_rooms, calculated_host_listings_count_shared_rooms
# - Categorical with levels:
#
#         - host_response_time, neighbourhood, neighbourhood_cleansed, neighbourhood_group_cleansed, property_type, room_type, bathrooms_text, bed_type, calendar_updated
# - Categorical:
#
#         - available, host_is_superhost, host_has_profile_pic, host_identity_verified, has_availability, instant_bookable
# - Text:
#
#         - listing_url, source, name, description, neighborhood_overview, picture_url, host_url, host_name, host_since, host_location, host_about, host_thumbnail_url, host_picture_url, host_neighbourhood, host_verifications, amenities, license
# - Date:
#
#         - last_scraped, first_review, last_review, calendar_last_scraped

# %%
# Describe the data
print(df_airbnb_listings.shape)
df_airbnb_listings.describe()
# Out:
# (6809, 75)
#                  id     scrape_id       host_id  host_listings_count  \
# count  6.809000e+03  6.809000e+03  6.809000e+03          6809.000000
# mean   1.543801e+17  2.022121e+13  9.757724e+07             2.801146
# std    2.861175e+17  0.000000e+00  1.315182e+08            18.066322
# min    2.818000e+03  2.022121e+13  3.159000e+03             1.000000
# 25%    1.510977e+07  2.022121e+13  9.287585e+06             1.000000
# 50%    3.373018e+07  2.022121e+13  3.321458e+07             1.000000
# 75%    5.313791e+07  2.022121e+13  1.336823e+08             2.000000
# max    7.743397e+17  2.022121e+13  4.901557e+08           799.000000
#
#        host_total_listings_count  neighbourhood_group_cleansed     latitude  \
# count                6809.000000                           0.0  6809.000000
# mean                    4.819944                           NaN    52.366847
# std                    29.766061                           NaN     0.017026
# min                     1.000000                           NaN    52.290340
# 25%                     1.000000                           NaN    52.356040
# 50%                     1.000000                           NaN    52.366190
# 75%                     3.000000                           NaN    52.376630
# max                   799.000000                           NaN    52.425120
#
#          longitude  accommodates  bathrooms  ...  review_scores_cleanliness  \
# count  6809.000000   6809.000000        0.0  ...                6157.000000
# mean      4.890363      2.918784        NaN  ...                   4.760789
# std       0.035550      1.401175        NaN  ...                   0.316494
# min       4.755710      0.000000        NaN  ...                   1.000000
# 25%       4.866890      2.000000        NaN  ...                   4.670000
# 50%       4.888210      2.000000        NaN  ...                   4.860000
# 75%       4.908470      4.000000        NaN  ...                   5.000000
# max       5.026430     16.000000        NaN  ...                   5.000000
#
#        review_scores_checkin  review_scores_communication  \
# count            6157.000000                  6157.000000
# mean                4.880387                     4.890471
# std                 0.216868                     0.221001
# min                 1.000000                     1.000000
# 25%                 4.850000                     4.870000
# 50%                 4.950000                     4.970000
# 75%                 5.000000                     5.000000
# max                 5.000000                     5.000000
#
#        review_scores_location  review_scores_value  \
# count             6157.000000          6157.000000
# mean                 4.790138             4.650797
# std                  0.247403             0.305070
# min                  1.000000             1.000000
# 25%                  4.670000             4.510000
# 50%                  4.860000             4.700000
# 75%                  5.000000             4.830000
# max                  5.000000             5.000000
#
#        calculated_host_listings_count  \
# count                     6809.000000
# mean                         1.853576
# std                          2.561150
# min                          1.000000
# 25%                          1.000000
# 50%                          1.000000
# 75%                          1.000000
# max                         22.000000
#
#        calculated_host_listings_count_entire_homes  \
# count                                  6809.000000
# mean                                      0.975621
# std                                       1.292887
# min                                       0.000000
# 25%                                       0.000000
# 50%                                       1.000000
# 75%                                       1.000000
# max                                      14.000000
#
#        calculated_host_listings_count_private_rooms  \
# count                                   6809.000000
# mean                                       0.786606
# std                                        2.168739
# min                                        0.000000
# 25%                                        0.000000
# 50%                                        0.000000
# 75%                                        1.000000
# max                                       20.000000
#
#        calculated_host_listings_count_shared_rooms  reviews_per_month
# count                                  6809.000000        6161.000000
# mean                                      0.040828           1.226475
# std                                       0.440437           2.335964
# min                                       0.000000           0.010000
# 25%                                       0.000000           0.280000
# 50%                                       0.000000           0.610000
# 75%                                       0.000000           1.410000
# max                                       8.000000         106.740000
#
# [8 rows x 40 columns]

# %%
# Get all the numerical columns names
numerical_columns = df_airbnb_listings.select_dtypes(include=np.number).columns
print(numerical_columns)
# Out:
# Index(['id', 'scrape_id', 'host_id', 'host_listings_count',
#        'host_total_listings_count', 'neighbourhood_group_cleansed', 'latitude',
#        'longitude', 'accommodates', 'bathrooms', 'bedrooms', 'beds',
#        'minimum_nights', 'maximum_nights', 'minimum_minimum_nights',
#        'maximum_minimum_nights', 'minimum_maximum_nights',
#        'maximum_maximum_nights', 'minimum_nights_avg_ntm',
#        'maximum_nights_avg_ntm', 'calendar_updated', 'availability_30',
#        'availability_60', 'availability_90', 'availability_365',
#        'number_of_reviews', 'number_of_reviews_ltm', 'number_of_reviews_l30d',
#        'review_scores_rating', 'review_scores_accuracy',
#        'review_scores_cleanliness', 'review_scores_checkin',
#        'review_scores_communication', 'review_scores_location',
#        'review_scores_value', 'calculated_host_listings_count',
#        'calculated_host_listings_count_entire_homes',
#        'calculated_host_listings_count_private_rooms',
#        'calculated_host_listings_count_shared_rooms', 'reviews_per_month'],
#       dtype='object')

# %%
# Drop the columns that are not useful for the analysis
df_airbnb_listings = df_airbnb_listings.drop(['id', 'source', 'name', 'description', 'picture_url', 'host_url', 'host_name', 'host_about', 'neighbourhood', 'host_location', 'neighborhood_overview', 'listing_url', 'host_thumbnail_url', 'neighbourhood_cleansed', 'host_thumbnail_url', 'host_picture_url', 'host_neighbourhood'], axis=1)

categorical_columns = df_airbnb_listings.select_dtypes(include='object').columns

# Print value counts for the categorical columns
for col in categorical_columns:
    # print the column name
    print(col)
    # print the value counts
    print(df_airbnb_listings[col].value_counts())
# Out:
# last_scraped
# 2022-12-05    6808
# 2022-12-17       1
# Name: last_scraped, dtype: int64
# host_since
# 2014-04-22    25
# 2018-07-20    23
# 2019-01-17    15
# 2020-08-25    15
# 2013-04-06    15
#               ..
# 2012-12-03     1
# 2015-12-12     1
# 2012-04-25     1
# 2016-12-13     1
# 2012-11-23     1
# Name: host_since, Length: 2666, dtype: int64
# host_response_time
# within an hour        2655
# within a day          1020
# within a few hours     989
# a few days or more      91
# Name: host_response_time, dtype: int64
# host_response_rate
# 100%    3653
# 90%      183
# 80%      115
# 96%       68
# 50%       65
# 0%        59
# 67%       54
# 75%       51
# 97%       50
# 86%       43
# 93%       40
# 70%       36
# 98%       34
# 83%       28
# 99%       27
# 88%       24
# 89%       23
# 78%       20
# 92%       19
# 84%       18
# 60%       18
# 95%       17
# 94%       17
# 91%       12
# 63%       10
# 33%        9
# 71%        8
# 81%        6
# 87%        4
# 57%        4
# 20%        4
# 40%        4
# 25%        3
# 30%        3
# 82%        3
# 77%        3
# 56%        3
# 43%        3
# 72%        2
# 73%        2
# 29%        2
# 11%        1
# 79%        1
# 36%        1
# 44%        1
# 85%        1
# 38%        1
# 53%        1
# 76%        1
# Name: host_response_rate, dtype: int64
# host_acceptance_rate
# 100%    2097
# 99%      320
# 50%      222
# 0%       184
# 67%      180
#         ...
# 7%         2
# 9%         1
# 12%        1
# 5%         1
# 15%        1
# Name: host_acceptance_rate, Length: 97, dtype: int64
# host_is_superhost
# f    5487
# t    1318
# Name: host_is_superhost, dtype: int64
# host_verifications
# ['email', 'phone']                    5491
# ['email', 'phone', 'work_email']       828
# ['phone']                              430
# ['phone', 'work_email']                 28
# []                                      22
# ['email']                                9
# ['email', 'phone', 'photographer']       1
# Name: host_verifications, dtype: int64
# host_has_profile_pic
# t    6765
# f      44
# Name: host_has_profile_pic, dtype: int64
# host_identity_verified
# t    5840
# f     969
# Name: host_identity_verified, dtype: int64
# property_type
# Entire rental unit                    2384
# Entire condo                          1284
# Private room in rental unit            520
# Entire home                            432
# Private room in bed and breakfast      294
# Entire townhouse                       213
# Entire loft                            186
# Private room in condo                  135
# Houseboat                              132
# Private room in home                   130
# Room in boutique hotel                 122
# Room in hotel                          117
# Private room in houseboat              102
# Private room in guest suite             99
# Private room in townhouse               91
# Boat                                    83
# Entire serviced apartment               70
# Private room in boat                    57
# Private room in loft                    41
# Room in bed and breakfast               26
# Shared room in hostel                   23
# Entire guest suite                      23
# Room in aparthotel                      20
# Entire villa                            20
# Private room in hostel                  19
# Entire vacation home                    18
# Private room in serviced apartment      17
# Private room in casa particular         16
# Entire guesthouse                       15
# Private room in guesthouse              13
# Room in hostel                          12
# Entire place                             9
# Private room                             9
# Private room in villa                    8
# Private room in farm stay                7
# Shared room in rental unit               6
# Tiny home                                6
# Room in serviced apartment               6
# Private room in earthen home             6
# Entire cabin                             4
# Camper/RV                                4
# Entire cottage                           4
# Shared room in houseboat                 4
# Private room in tiny home                3
# Tower                                    2
# Entire chalet                            2
# Private room in cabin                    2
# Shared room in home                      2
# Bus                                      1
# Shared room in aparthotel                1
# Private room in vacation home            1
# Shared room in farm stay                 1
# Yurt                                     1
# Barn                                     1
# Shared room in bed and breakfast         1
# Cave                                     1
# Shared room in boat                      1
# Private room in bungalow                 1
# Private room in nature lodge             1
# Name: property_type, dtype: int64
# room_type
# Entire home/apt    4910
# Private room       1798
# Hotel room           62
# Shared room          39
# Name: room_type, dtype: int64
# bathrooms_text
# 1 bath               2820
# 1.5 baths            1917
# 1 private bath        837
# 2 baths               381
# 1 shared bath         349
# 1.5 shared baths      177
# 2.5 baths             146
# 3 baths                80
# 3.5 baths              23
# 0 shared baths         16
# 0 baths                11
# Half-bath               5
# 5 baths                 5
# 2 shared baths          5
# 4.5 baths               5
# Private half-bath       4
# 4 baths                 4
# 3 shared baths          4
# Shared half-bath        2
# 5.5 baths               2
# 4 shared baths          2
# 17 baths                1
# Name: bathrooms_text, dtype: int64
# amenities
# ["Wifi", "Long term stays allowed", "Shampoo", "TV", "Hair dryer", "Self check-in", "Building staff", "Heating"]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               9
# ["Smoke alarm", "Fire extinguisher", "TV", "Waterfront", "Luggage dropoff allowed", "Paid parking off premises", "Coffee maker", "Heating", "Patio or balcony", "Bed linens", "Breakfast", "Wifi", "Washer", "Security cameras on property", "Mini fridge", "Essentials", "First aid kit", "Extra pillows and blankets", "Hot water kettle", "Body soap", "Portable fans", "Dryer", "Shampoo", "Hair dryer", "Hot water", "Lock on bedroom door", "Safe", "Hangers", "Long term stays allowed", "Iron", "Clothing storage", "Shower gel", "Refrigerator", "Conditioner"]                                       8
# ["Smoke alarm", "Fire extinguisher", "TV", "Luggage dropoff allowed", "Heating", "Bed linens", "Wifi", "Security cameras on property", "Mini fridge", "Essentials", "Coffee maker: Nespresso", "First aid kit", "Air conditioning", "Body soap", "Shampoo", "Hair dryer", "Hot water", "Lock on bedroom door", "Hangers", "Long term stays allowed", "Iron", "Elevator", "Conditioner"]                                                                                                                                                                                                                        6
# ["Smoke alarm", "Kitchen", "Wifi", "Long term stays allowed", "Washer", "TV"]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  6
# ["Smoke alarm", "Private entrance", "Hangers", "Wifi", "Long term stays allowed", "Iron", "Elevator", "Dedicated workspace", "Shampoo", "Essentials", "TV", "Hair dryer", "Lock on bedroom door", "Heating"]                                                                                                                                                                                                                                                                                                                                                                                                   6
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               ..
# ["Smoke alarm", "Spray Conditioner from Hemma conditioner", "Waterfront", "Self check-in", "Fire pit", "Coffee maker", "Heating", "Patio or balcony", "BBQ grill", "Bed linens", "Private entrance", "Outdoor furniture", "Wifi", "Microwave", "Mini fridge", "Essentials", "Cleaning products", "Outdoor dining area", "Carbon monoxide alarm", "Hot water kettle", "Portable fans", "Shampoo", "Hair dryer", "Hot water", "Lock on bedroom door", "Dishes and silverware", "EV charger", "Lockbox", "Wine glasses", "Hangers", "Long term stays allowed", "Pets allowed", "Coffee", "Iron", "Shower gel"]    1
# ["Smoke alarm", "Fire extinguisher", "Stove", "Dishwasher", "Oven", "Coffee maker", "Heating", "Wifi", "Microwave", "Washer", "Essentials", "First aid kit", "Carbon monoxide alarm", "Single level home", "Cooking basics", "Dryer", "Shampoo", "Hair dryer", "Hot water", "Dishes and silverware", "Hangers", "Kitchen", "Long term stays allowed", "Iron", "TV with standard cable", "Refrigerator"]                                                                                                                                                                                                        1
# ["Smoke alarm", "Coffee maker", "Kitchen", "Wifi", "Fire extinguisher", "Cooking basics", "Washer", "Long term stays allowed", "Dryer", "Elevator", "Essentials", "Host greets you", "Hot water", "Dishes and silverware", "TV with standard cable", "Dishwasher", "First aid kit", "Carbon monoxide alarm", "Heating"]                                                                                                                                                                                                                                                                                        1
# ["Smoke alarm", "Wifi", "Fire extinguisher", "Long term stays allowed", "Dryer", "Dedicated workspace", "Shampoo", "Essentials", "Heating"]                                                                                                                                                                                                                                                                                                                                                                                                                                                                    1
# ["Smoke alarm", "BBQ grill", "Outdoor dining area", "Kitchen", "Wifi", "Fire extinguisher", "Outdoor furniture", "Washer", "Dryer", "Dedicated workspace", "Shampoo", "Essentials", "High chair", "Hammock", "TV with standard cable", "Host greets you", "First aid kit", "Refrigerator", "Carbon monoxide alarm", "Heating"]                                                                                                                                                                                                                                                                                 1
# Name: amenities, Length: 6634, dtype: int64
# price
# $200.00    267
# $150.00    239
# $250.00    218
# $300.00    169
# $100.00    129
#           ...
# $614.00      1
# $528.00      1
# $373.00      1
# $322.00      1
# $686.00      1
# Name: price, Length: 542, dtype: int64
# has_availability
# t    6756
# f      53
# Name: has_availability, dtype: int64
# calendar_last_scraped
# 2022-12-05    6808
# 2022-12-17       1
# Name: calendar_last_scraped, dtype: int64
# first_review
# 2022-09-11    31
# 2022-05-29    24
# 2022-11-13    23
# 2022-07-24    23
# 2022-04-18    21
#               ..
# 2018-11-30     1
# 2019-11-20     1
# 2019-01-06     1
# 2015-02-23     1
# 2012-11-29     1
# Name: first_review, Length: 2288, dtype: int64
# last_review
# 2022-11-20    218
# 2022-11-27    212
# 2022-11-13    131
# 2022-11-28    128
# 2022-10-23    123
#              ...
# 2017-04-23      1
# 2018-08-30      1
# 2021-12-03      1
# 2018-01-27      1
# 2018-04-06      1
# Name: last_review, Length: 888, dtype: int64
# license
# Exempt                      567
# 0363 78AD 8875 790E 3C05     13
# ABCD 1234 AB12 89EF A0F9     12
# 0363 13D0 1F48 9D5D 2CD4      6
# 0363 45EF 2B9F 6E98 6026      5
#                            ...
# 0363 E72E C34E F8BC 332A      1
# 0363 127F D48F 968C B70B      1
# 0363 76B4 6789 47D1 EF52      1
# 0363FA6883EACCAAC70B          1
# 0363 9611 7834 EC7F E5BB      1
# Name: license, Length: 5662, dtype: int64
# instant_bookable
# f    5286
# t    1523
# Name: instant_bookable, dtype: int64

# %% [markdown]
# # Mapa de calor de correlaciones
#
# Este mapa de calor nos permite ver las correlaciones entre las variables numéricas del dataset. Se puede ver que las variables que tienen una correlación más alta son:

# %%
# print the heatmap of the correlation matrix
plt.figure(figsize=(10,10))
sns.heatmap(df_airbnb_listings.corr(), annot=True, fmt='.2f', cmap='coolwarm')
plt.show()

# %% [markdown]
# En este análisis se puede ver que las variables que tienen una correlación más alta son:
#
# - availability_30 y availability_60
# - availability_60 y availability_90
# - availability_90 y availability_365
# - availability_365 y number_of_reviews
# - price y accommodates
# - price y bedrooms
# - price y beds
# - rating y number_of_reviews
# - rating y number_of_reviews_ltm
# - popularity y number_of_reviews
# - utilization_index y availability_365

# %% [markdown]
# # Explicación de selección de modelo

# %% [markdown]
# > We choose to use the LinearRegression model because it is the most simple model to use and it is the most used model for this type of data. We also choose to use the StandardScaler because it is the most used scaler for this type of data.

# %% [markdown]
# # Create a train and test set

# %%
# Create the train and test data
X_train, X_test, y_train, y_test = train_test_split(df_airbnb_listings.drop(['price'], axis=1), df_airbnb_listings['price'], test_size=0.2, random_state=42)

# Create the scaler object with a range of 0-1
scaler = StandardScaler()

# Fit on the training data
scaler.fit(X_train)

# Transform both the training and test data
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# Create the linear regression model with scikit-learn
reg = LinearRegression()

# Fit the model to the training data
reg.fit(X_train, y_train)

# %% [markdown]
# # Metrics for the model
#
# En este caso se utilizo el error cuadratico medio (MSE) para medir la calidad del modelo. Tambien se utilizo el error absoluto medio (MAE) para medir la calidad del modelo. Adicionalmente se utilizo el coeficiente de determinación (R2) para medir la calidad del modelo.

# %%
# Predict on the test data: y_pred
y_pred = reg.predict(X_test)

# Compute and print R^2 and RMSE
print("R^2: {}".format(reg.score(X_test, y_test)))
rmse = np.sqrt(metrics.mean_squared_error(y_test, y_pred))
print("Root Mean Squared Error: {}".format(rmse))

# Compute 5-fold cross-validation scores: cv_scores
cv_scores = cross_val_score(reg, X_train, y_train, cv=5)
